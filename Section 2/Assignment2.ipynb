# %% [markdown]
# # ELE 251 Assignment 2

# %% [markdown]
# <div style="border-left: 4px solid #0078D7; padding: 10px; background-color: #f3f9ff;">
#   <h2 style="margin: 0;">Instruction</h2>
# </div>
#
# * The Final submussion must be .pdf
# * Each student will have different numbers in the questions. Run the code cell to get your own numbers.
# * All questions are in Zero Initial Condition.

# %%
# This code generates customized numbers for each student
# Run this code and input your "First name Last name"
# For example, Yue Cao
import hashlib

def generate_numbers(name, count=4):
    unique_numbers = set()
    counter = 0

    while len(unique_numbers) < count:
        unique_input = f"{name}{counter}"
        hash_value = hashlib.sha256(unique_input.encode()).hexdigest()
        number = int(hash_value, 16) % 90 + 10
        unique_numbers.add(number)
        counter += 1

    return list(unique_numbers)

student_name = input("Enter the student's name: ")
numbers = generate_numbers(student_name)

variables = {}
for i, num in enumerate(numbers):
    var_name = f"Constant{chr(65+i)}"
    variables[var_name] = num
    globals()[var_name] = num

for var_name, value in variables.items():
    print(f"{var_name} = {value}")

# %% [markdown]
# <div style="border-left: 4px solid #28a745; padding: 10px; background-color: #f9fff3; margin-top: 10px;">
#   <h2 style="margin: 0;">Q 1: Sine Response</h2>
# </div>

# %% [markdown]
# Consider a system in ODE:
#
# $$2\frac{d^2 y(t)}{dt^2} + \frac{d y(t)}{dt} + 80y(t) = \mathrm{ConstantA} \cdot x(t)$$
#
# * $y(t)$ is the output
# * $x(t)$ is the input

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q1.1</strong>
# </span>
#
# Express the system transfer function.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q1.2</strong>
# </span>
#
# Consider input $x(t) = 20\sin(0.06t)+ 10\cos(0.06t)$
#
# Express $x(t)$ as Complex Exponential form.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q1.3, 1.4</strong>
# </span>
#
# In Python, plot the system response $y(t)$ and input $x(t)$ on the same figure.
# * Properly set the Time-Axis, so that you can observe both transient and steady state response.
# * You should use ```scipy.signal.lsim```
# * Show both code and plot

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q1.5</strong>
# </span>
#
# Read from your plot. Answer
# * The amplitude of $x(t)$
# * The amplitude of the steady state part of $y(t)$
# * The period of the steady state part of $y(t)$

# %% [markdown]
# <div style="border-left: 4px solid #28a745; padding: 10px; background-color: #f9fff3; margin-top: 10px;">
#   <h2 style="margin: 0;">Q 2: Cascaded System</h2>
# </div>

# %% [markdown]
# Consider a cascaded system with sine input.
#
# The system diagram shown in this picture:

# %% [markdown]
# ![Screenshot 2025-03-19 174919.png](attachment:6dabda18-332a-43ab-a0e3-a5590d96c9c8.png)

# %% [markdown]
# The sine signal is shown in this picture:

# %% [markdown]
# ![Screenshot 2025-03-19 175250.png](attachment:2614d3b8-56af-4c29-add5-6003c5f0605a.png)

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q2.1</strong>
# </span>

# %% [markdown]
# From the graph,
# * Read the rad/s frequency of the signal.
# * Write the Sine expression for $x(t)$.
# * Write the $x(t)$ in Phasor notation.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q2.2</strong>
# </span>
#
# Write the $x(t)$ in Phasor notation.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q2.3</strong>
# </span>

# %% [markdown]
# The system 1 transfer function is $\frac{1}{s+1}$
#
# Calculate its Phasor forms. Show code and result.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q2.4</strong>
# </span>
#
# The system 2 transfer function is $\dfrac{30}{20s+\mathrm{ConstantB} }$
#
# Calculate its Phasor forms. Show code and result.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q2.5</strong>
# </span>
#
# The system 3 Phasor is $100\angle 60 \mathrm{deg}$
#
# Calculate the Phasor for the output $y(t)$.
#
# Also write the $y(t)$ in sine form.

# %% [markdown]
# <div style="border-left: 4px solid #28a745; padding: 10px; background-color: #f9fff3; margin-top: 10px;">
#   <h2 style="margin: 0;">Q 3: System Analysis</h2>
# </div>

# %% [markdown]
# Consider a system:
#
# $$H(s)=20\frac{s+\mathrm{ConstantC}}{s^2+508s+4000}$$

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q3.1</strong>
# </span>
#
# Calculate the DC Gain of the system.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q3.2</strong>
# </span>
#
# Use ```scipy.signal.tf2zpk``` to obtain the zeros and poles of the system.
#
# Write the transfer function in zero-pole-gain form.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q3.3</strong>
# </span>
#
# From your Q3.2 result, direct calculate all 3 cut-off freqs of the system. Unit in Hz.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q3.4</strong>
# </span>
#
# Plot Bode Magnitude. Properly set the Freq-Axis so that all cut-off freqs are included.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q3.5</strong>
# </span>
#
# From your graph, what is the Magnitude at f=1 Hz? Answer in both dB and normal ratio.
#
# If a input sine signal is $5\sin(2\pi t) $, what will be the amplitude of the output signal?

# %% [markdown]
# <div style="border-left: 4px solid #28a745; padding: 10px; background-color: #f9fff3; margin-top: 10px;">
#   <h2 style="margin: 0;">Q 4: Filter Design</h2>
# </div>

# %% [markdown]
# Suppose you want to design a high-pass filter built by some resistors and capacitors.
#
# The transfer function is:
# $$H(s) = \frac{(1+R_2/R_3)sR_1C}{sR_1C+1}$$

# %% [markdown]
# **Design Requirement**:
#
# * Pass-band Gain: 5 dB
# * Cut-off freq: ConstantD$\times 100$ Hz

# %% [markdown]
# **Design Constraints**:
#
# You only have these limited selections on resistors and capacitors:
#
# This is called E6-series preferred numbers.
# https://en.wikipedia.org/wiki/E_series_of_preferred_numbers#Examples

# %% [markdown]
# ![Picture1.png](attachment:628afb33-6262-439d-b170-5acb739b152c.png)

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q4.1</strong>
# </span>
#
# Using the given transfer function, express the Pass-band Gain in terms of $R_1$, $R_2$, $R_3$, $C$. (you may not need all 4)

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q4.2</strong></span>
#
# Using the given transfer function, express the Cut-off freq in terms of $R_1$, $R_2$, $R_3$, $C$. (you may not need all 4)

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q4.3</strong></span>
#
# Based on the design requirements and design constraints, pick your RC components.
#
# (small deviation versus design requirements is allowed)
# * $R_1$:
# * $R_2$:
# * $R_3$:
# * $C$:

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q4.4</strong></span>
#
# Based on your selected components,
#
# * Compute the actual Pass-band Gain and Cut-off freq.
# * Write down the actual transfer function with numerical values plugged in.

# %% [markdown]
# <span style="border-left: 4px solid #FFA500; padding: 5px; background-color: #FFF4E5; display: inline-block;">
#     <strong>Q4.5</strong>
# </span>
#
# Sketch the Bode Magnitude plot for the actual transfer function.
#
# Properly set your Freq-Axis, so that the cut-off frequency is included.

# %% [markdown]
# <div style="border-left: 4px solid #28a745; padding: 10px; background-color: #f9fff3; margin-top: 10px;">
#   <h2 style="margin: 0;">Submit in .pdf</h2>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #28a745; padding: 10px; background-color: #f9fff3; margin-top: 10px;">
#   <h2 style="margin: 0;">Make sure all your answer cells are rendered</h2>
# </div>
